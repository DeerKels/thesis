# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np

# %%
selected = pd.read_csv('/Users/jixinge/Thesis Data/Unique.csv', converters={'Global Company Key':str})
selected['Selected'] = 1

# %%
### Filtered_df stores all public stocks on compustat after taking out the taken-private companies
filtered = pd.read_csv('/Users/jixinge/Thesis Data/firms_dropped.csv', converters={'Global Company Key':str}, dtype='string')
filtered['Selected'] = 0
# Out:
# /Users/jixinge/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: ParserWarning: Both a converter and dtype were specified for column Global Company Key - only the converter will be used.
#   return func(*args, **kwargs)

# %%
selected.columns
# Out:
# Index(['Global Company Key', 'Data Date', 'Ticker Symbol', 'CUSIP',
#        'Company Name', 'Accounting Changes - Cumulative Effect',
#        'Accumulated Other Comprehensive Income (Loss)',
#        'Current Assets - Other - Total', 'Current Assets - Total',
#        'Other Long-term Assets',
#        ...
#        'Implied Option Expense.1', 'Research and Development Expense.1',
#        'Selling, General and Administrative Expenses.1', 'CIK Number',
#        'Active/Inactive Status Marker', 'Common Shares Traded - Quarter',
#        'Dividends per Share - Pay Date - Quarter',
#        'Div per Share - Exdate - Quarter', 'Market Value - Total', 'Selected'],
#       dtype='object', length=610)

# %%
def rows_matching_gvkey(gvkey, df):
  return df.loc[df['Global Company Key'] == gvkey]

# %%
gvkeys = filtered['Global Company Key'].unique()
# Out:
# 11538

# %%
not_selected = pd.DataFrame(columns=selected.columns)
gvkeys = []

for i in range (80000):
    row = filtered.sample(n=1)
    key = list(row['Global Company Key'])[0]
    if key not in gvkeys:
        gvkeys.append(key)
        not_selected = not_selected.append(pd.DataFrame(row), ignore_index=True)
        
not_selected
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/h7/z83wtj054vn5wyb4xp3896wc0000gn/T/ipykernel_21464/1435679657.py in <module>
#       2     return group.sample(1, random_state=np.random.default_rng().integers(0, np.iinfo(np.int32).max))
#       3
# ----> 4 shortened = filtered.groupby('Global Company Key', group_keys=False).apply(select_random_row)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1421         with option_context("mode.chained_assignment", None):
#    1422             try:
# -> 1423                 result = self._python_apply_general(f, self._selected_obj)
#    1424             except TypeError:
#    1425                 # gh-20949
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same)
# ...

# %%
filtered.drop(columns=['Ticker Symbol', 'CUSIP', 'Company Name', 'CIK Number', 'Active/Inactive Status Marker'], inplace=True)
selected.drop(columns=['Ticker Symbol', 'CUSIP', 'Company Name', 'CIK Number', 'Active/Inactive Status Marker'], inplace=True)

# %%
features = filtered.columns[2:-1]
X = filtered[features]
y = filtered['Selected']

# Split into training and testing sets (15% train, 85% test in this example)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.85, random_state=42)

# %%
selected_y = selected['Selected']
selected = selected[selected.columns[2:-1]]

# %%
X_train = pd.concat([X_train, selected])
y_train = pd.concat([y_train, selected_y])

# %%
X_train
# Out:
#        Accounting Changes - Cumulative Effect  \
# 348495                                   <NA>
# 250424                                 0.0000
# 612912                                 0.0000
# 154976                                 0.0000
# 649740                                 0.0000
# ...                                       ...
# 337                                       NaN
# 338                                       NaN
# 339                                       NaN
# 340                                       NaN
# 341                                       NaN
#
#        Accumulated Other Comprehensive Income (Loss)  \
# 348495                                          <NA>
# 250424                                        0.0000
# 612912                                       32.6270
# 154976                                      -34.8000
# 649740                                      -37.0080
# ...                                              ...
# ...

# %% [markdown]
# Drop all rows that are more than 50% NAs

# %%
X_train = sm.add_constant(X_train)
model = sm.OLS(y_train, X_train).fit()
print(model.summary())

# %% [markdown]
# # IGNORE BELOW

# %% [markdown]
# 1.  get unique gvkeys are in that year.
# 2.  select 2000 unique gvkeys
# 3.  for each gvkey
#   4.      get all rows in not_selected that correspond to that gvkey
#   5.      randomly select one row.

# %%
def rows_matching_year(year, df):
  return df.loc[df['Year'] == year]

def rows_matching_gvkey(gvkey, df):
  return df.loc[df['Global Company Key'] == gvkey]

# %%
import numpy as np
import random

# %%
not_selected = pd.DataFrame(columns=selected.columns)

# %%
train = pd.DataFrame(columns=selected.columns)  # Initialize an empty DataFrame for the "train" data

selection_percentage = 0.10  # 10%

for year in compustat['Year'].unique():
    year_data = compustat_df[compustat_df['Year'] == year]
    unique_gvkey_count = year_data['gvkey'].nunique()

    rows_to_select = int(len(year_data) * selection_percentage)
    selected_rows = year_data.sample(rows_to_select)
    train = train.append(selected_rows, ignore_index=True)
    compustat = compustat.drop(selected_rows.index)

# %%
### Convert Data Date into datetime format and create a new column that only keeps the year
filtered['Data Date'] = pd.to_datetime(filtered['Data Date'])
filtered['Year'] = filtered['Data Date'].dt.year

for year in range(1981, 2024):
  keys = random.shuffle(rows_matching_year(year, filtered)['Global Company Key'].unique())
  if (len(keys) >= 2000):
    keys = keys[:2000]
    #keys = random.sample(keys, 2000)
  for key in keys:
    row = rows_matching_gvkey(key, filtered).sample(frac=1.0, random_state=42).head(1)
    not_selected.append(row)
    filtered = filtered.drop(index = row.index)
    ### export the filtered df

# %%
filtered.to_csv('testing.csv', index=False)

# %%
not_selected.to_csv('two_k.csv', index=False)

# %%
keys = random.shuffle(list(rows_matching_year(year, filtered)['Global Company Key'].unique()))

if (len(keys) >= 2000):
    keys = keys[:2000]
keys
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-f0a66aae1017> in <cell line: 3>()
#       1 keys = random.shuffle(list(rows_matching_year(year, filtered)['Global Company Key'].unique()))
#       2
# ----> 3 if (len(keys) >= 2000):
#       4     keys = keys[:2000]
#       5 keys
#
# TypeError: object of type 'NoneType' has no len()
